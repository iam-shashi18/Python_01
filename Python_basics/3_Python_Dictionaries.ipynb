# %% [markdown]
# #Dictionary
#
# A dictionary is a collection which is **unordered, changeable and indexed**. In Python dictionaries are written with **curly brackets** { }, and they have **keys and values** in each **items**.
#
# ---

# %%
# Create and print a dictionary:

xyz =	{
  "brand": "Ford",
  "model": "Mustang",
  (1,2): 1964
}
print(xyz)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', (1, 2): 1964}

# %% [markdown]
# **Accessing Items**
#
# You can access the items of a dictionary by referring to its key name, inside square brackets:
#
# ---

# %%
thisdict =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
print(thisdict["year"])
# Out:
# 1964

# %% [markdown]
# here is also a method called **get() ** that will give you the same result:

# %%
thisdict =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
print(thisdict.get("model"))
# Out:
# Mustang

# %% [markdown]
# **Change Values**
#
# You can change the value of a specific item by referring to its key name:
#
# ---

# %%
thisdict =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

thisdict["year"] = 2018
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2018}

# %% [markdown]
# **Loop Through a Dictionary**
#
# You can loop through a dictionary by using a for loop.
#
# When looping through a dictionary, the return value are the keys of the dictionary, but there are methods to return the values as well.
#
# ---

# %%
#Print all key names in the dictionary, one by one:

thisdict =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

for x in thisdict:
  print(x)
# Out:
# brand
# model
# year

# %% [markdown]
# Print all values in the dictionary, one by one:

# %%
thisdict =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

for x in thisdict:
  print(thisdict[x])
# Out:
# Ford
# Mustang
# 1964

# %% [markdown]
# You can also use the values() function to return values of a dictionary:

# %%
thisdict =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
for x in thisdict.values():
  print(x)
# Out:
# Ford
# Mustang
# 1964

# %% [markdown]
# Loop through both keys and values, by using the items() function:

# %%
for x,y in thisdict.items():
  print(x, y)
# Out:
# brand Ford
# model Mustang
# year 1964

# %% [markdown]
# **Check if Key Exists**
#
# To determine if a specified key is present in a dictionary use the in keyword:
#
# ---

# %%
thisdict =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
if "model" in thisdict:
  print("Yes, 'model' is one of the keys in the thisdict dictionary")
# Out:
# Yes, 'model' is one of the keys in the thisdict dictionary

# %% [markdown]
# **Dictionary Length**
#
# To determine how many items (key-value pairs) a dictionary has, use the **len() method**.
#
# ---

# %%
thisdict =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
print(len(thisdict))
# Out:
# 3

# %% [markdown]
# **Adding Items**
#
# Adding an item to the dictionary is done by **using a new index key and assigning a value** to it:
#
# ---

# %%
thisdict =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict["color"]="Red"
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964, 'color': 'Red'}

# %% [markdown]
# **Removing Items**
#
# There are several methods to remove items from a dictionary:
#
# ---
#
# The **pop() method removes** the item with the specified key name:

# %%
thisdict =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.pop("model")
print(thisdict)
# Out:
# {'brand': 'Ford', 'year': 1964}

# %% [markdown]
# The **popitem() method** removes the last inserted item (in versions before 3.7, a random item is removed instead):

# %%
thisdict =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.popitem()
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang'}

# %% [markdown]
# The **del keyword **removes the item with the specified key name:

# %%
thisdict =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
del thisdict["model"]
print(thisdict)
# Out:
# {'brand': 'Ford', 'year': 1964}

# %% [markdown]
# The del keyword can also delete the dictionary completely:

# %%
thisdict =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
del thisdict
print(thisdict) #this will cause an error because "thisdict" no longer exists.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-10-776456522.py in <cell line: 0>()
#       5 }
#       6 del thisdict
# ----> 7 print(thisdict) #this will cause an error because "thisdict" no longer exists.
#
# NameError: name 'thisdict' is not defined

# %% [markdown]
# The **clear() keyword ** empties the dictionary:

# %%
thisdict =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.clear()
print(thisdict)
# Out:
# {}

# %% [markdown]
# **The dict() Constructor**
#
# It is also possible to use the dict() constructor to make a dictionary:
#
# ---

# %%
thisdict =	dict(brand="Ford", model="Mustang", year=1964)
# note that keywords are not string literals
# note the use of equals rather than colon for the assignment
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %% [markdown]
# #Dictionary Methods
#
# Python has a set of built-in methods that you can use on dictionaries.
#
# ---
#
# **Method**                    	**Description**
#
# ---
#
# **clear()**	: Removes all the elements from the dictionary
#
# **copy()** :	Returns a copy of the dictionary
#
# **fromkeys()**	: Returns a dictionary with the specified keys and values
#
# **get()**	: Returns the value of the specified key
#
# **items()**	: Returns a list containing the a tuple for each key value pair
#
# **keys()**	: Returns a list containing the dictionary's keys
#
# **pop()**	: Removes the element with the specified key
#
# **popitem()**	: Removes the last inserted key-value pair
#
# **setdefault()** :	Returns the value of the specified key. If the key does not exist: insert the key, with the specified value
#
# **update()** :	Updates the dictionary with the specified key-value pairs
#
# **values()**	Returns a list of all the values in the dictionary

# %% [markdown]
# ---
# ## Nested Dictionaries
#
# A dictionary can contain another dictionary as a value — useful for structured records like student data:
#
# ```python
# student = {
#     "name": "Priya",
#     "age": 20,
#     "marks": {"math": 90, "science": 85, "english": 78}
# }
#
# # Access nested value:
# print(student["marks"]["math"])   # 90
# ```

# %%
student = {
    "name": "Priya",
    "age": 20,
    "marks": {"math": 90, "science": 85, "english": 78}
}

print(student["name"])                  # Priya
print(student["marks"]["math"])          # 90
print(student["marks"]["science"])       # 85

# Loop through marks
for subject, score in student["marks"].items():
    print(f"  {subject}: {score}")

# %% [markdown]
# ---
# ## Safe Access with `.get()` and Default Values
#
# Accessing a key that doesn't exist raises a `KeyError`. The `.get()` method is safer — it returns `None` (or a default you specify) instead of crashing:
#
# ```python
# profile = {"username": "coder99"}
#
# # Unsafe — raises KeyError if 'phone' doesn't exist:
# # print(profile["phone"])   ← KeyError!
#
# # Safe — returns the default instead:
# print(profile.get("phone", "Not provided"))  # Not provided
# print(profile.get("username", "Anonymous"))   # coder99
# ```

# %%
profile = {"username": "coder99", "email": "coder@mail.com"}

print(profile.get("phone", "Not provided"))   # key missing → default
print(profile.get("username", "Anonymous"))    # key exists → returns value
print(profile.get("address"))                  # no default → returns None

# %% [markdown]
# ---
# ## Dictionary Comprehension
#
# Just like list comprehensions, you can build dictionaries concisely:
#
# ```python
# # Squares dictionary: {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
# squares = {x: x**2 for x in range(1, 6)}
#
# # With condition — only even numbers:
# even_squares = {x: x**2 for x in range(1, 11) if x % 2 == 0}
# ```
#
# **General syntax:** `{key_expr: value_expr for item in iterable if condition}`

# %%
squares = {x: x**2 for x in range(1, 6)}
print(squares)

# Only even squares
even_squares = {x: x**2 for x in range(1, 11) if x % 2 == 0}
print(even_squares)

# Invert a dictionary (swap keys and values)
original = {"a": 1, "b": 2, "c": 3}
inverted = {v: k for k, v in original.items()}
print(inverted)

# %% [markdown]
# ---
# # 📝 Assignments – Python Dictionaries
# ---

# %% [markdown]
# ## Task 1 – Student Record
#
# **Problem:** Create and manipulate a student dictionary:
# - Start: `name: "Rahul", age: 21, grade: "A", subject: "Mathematics"`
# 1. Print only the name and grade
# 2. Add `city: "Bangalore"`
# 3. Update age to 22
# 4. Print the final dictionary
#
# **💡 Hints:** Access with `dict["key"]`; add/update with `dict["key"] = value`

# %%
# Task 1 – Student Record
student = {"name": "Rahul", "age": 21, "grade": "A", "subject": "Mathematics"}

# %% [markdown]
# ## Task 2 – Safe Access with `.get()`
#
# **Problem:** `profile = {"username": "coder99", "email": "coder@mail.com"}`
# 1. Access `"phone"` safely with a default `"Not provided"`
# 2. Access `"username"` with `.get()`
#
# **Expected output:**
# ```
# phone: Not provided
# username: coder99
# ```
#
# **💡 Hint:** `profile.get("phone", "Not provided")`

# %%
# Task 2 – Safe Access
profile = {"username": "coder99", "email": "coder@mail.com"}

# %% [markdown]
# ## Task 3 – Inventory Loop
#
# **Problem:** `inventory = {"apples": 50, "bananas": 30, "oranges": 20, "grapes": 45}`
# 1. Print each item with its quantity: `"apples: 50"`
# 2. Calculate and print the total stock
#
# **Expected output:**
# ```
# apples: 50
# bananas: 30
# oranges: 20
# grapes: 45
# Total stock: 145
# ```
#
# **💡 Hints:** `.items()` gives key-value pairs; `sum(inventory.values())` for total

# %%
# Task 3 – Inventory Loop
inventory = {"apples": 50, "bananas": 30, "oranges": 20, "grapes": 45}

# %% [markdown]
# ## Task 4 – Word Frequency Counter
#
# **Problem:** Count how many times each word appears:
# `sentence = "the cat sat on the mat the cat is fat"`
#
# **Expected output:**
# ```
# {'the': 3, 'cat': 2, 'sat': 1, 'on': 1, 'mat': 1, 'is': 1, 'fat': 1}
# ```
#
# **💡 Hints:**
# - `sentence.split()` splits into a list of words
# - Loop through words; if word already in dict: `freq[word] += 1`, else: `freq[word] = 1`

# %%
# Task 4 – Word Frequency Counter
sentence = "the cat sat on the mat the cat is fat"
freq = {}

# %% [markdown]
# ## 🚀 Bonus – Odd/Even Dictionary
#
# **Problem:** Use dictionary comprehension to create `{1: 'odd', 2: 'even', 3: 'odd', ...}` for numbers 1 to 10.
#
# **Expected output:**
# ```
# {1: 'odd', 2: 'even', 3: 'odd', 4: 'even', 5: 'odd', 6: 'even', 7: 'odd', 8: 'even', 9: 'odd', 10: 'even'}
# ```
#
# **💡 Hint:** `{n: "even" if n%2==0 else "odd" for n in range(1,11)}`

# %%
# Bonus – Odd/Even Dictionary
