# %% [markdown]
# # 1. Arithmetic Operator :
#
# ---
#
#
# Arithmetic operators are used with numeric values to perform common mathematical operations:
# (https://www.w3schools.com/python/python_operators.asp)

# %%
# Declare the numeric variable
a=5
b=3

# %%
#1. Addition (+)
print(a+b)
# Out:
# 8

# %%
#2. Subtraction (-)
print(a-b)
# Out:
# 2

# %%
#3. Multiplication (*)
print(a*b)
# Out:
# 15

# %%
#4. Division (/)
print(a/b)
# Out:
# 1.6666666666666667

# %%
#5. Modulus(%)
print(a%b)
# Out:
# 2

# %%
#6. Exponentiation (**)
print(a**b)
# Out:
# 125

# %%
#7. Floor Division (//)
print(a//b)
# Out:
# 1

# %% [markdown]
# # 2. Assignment Operators:
#
# ---
#
# Assignment operators are used to assign values to variables:

# %%
# Declare variables
a=30
b=30

# %%
# '=' Operator
b = 20

# %%
# "+=" Operator
a+=b
print(a)
# Out:
# 60

# %%
# '-=' Operator
a-=b
print(a)
# Out:
# 30

# %%
# '*=' Operator
a*=b
print(a)
# Out:
# 600

# %%
# '/=' Operator
a/=b
print(a)
# Out:
# 30.0

# %%
# '%=' Operator
a%=b
print(a)
# Out:
# 10.0

# %%
# '//=' Operator
a//=b
print(a)
# Out:
# 0.0

# %%
# "**="
a**=b
print(a)
# Out:
# 0.0

# %% [markdown]
# # 3. Comparison Operators:
#
# ---
#
# Comparison operators are used to compare two values:

# %%
# Declare Variable
a = 30
b = 20

# %%
# Equal (==) Operator
print(a==b)
# Out:
# False

# %%
# Not equal (!=) Operator
print(a!=b)
# Out:
# True

# %%
# Greater than (>) Operator
print(a>b)
# Out:
# False

# %%
# Less than (<) Operator
print(a<b)
# Out:
# False

# %%
# Greater than or equal to (>=) Operator
print(a>=b)
# Out:
# True

# %%
# Less than or equal to (<=) Operator
print(a<=b)
# Out:
# False

# %% [markdown]
# # 4. Logical Operators:
#
# ---
#
# Logical operators are used to combine conditional statements:

# %%
# Declare variables
a=10
b=50

# %%
# 'and' Operator : Returns True if both statements are true
print(a and b)
print(a < 50 and  b < 10)
# Out:
# 50
# False

# %%
# 'or' Operator : Returns True if one of the statements is true
print(a or b)
print(a < 50 or b < 4)
# Out:
# 10
# True

# %%
# 'not' Operator: Reverse the result, returns False if the result is true
print(not(a < 5 and b < 10))
# Out:
# True

# %% [markdown]
# # 5. Bitwise operators
#
# ---
#
#
# Bitwise operators are used to compare (binary) numbers:

# %%
# Declare variable
a=13
b=35
c=10
d = format(c, 'b')
g = bin(10)
e = "10110"
f = int(e, 2)   # base=0 lets int() infer the prefix

# %%
print(a)
print(b)
print(c)
print(d)
print(g)
print(e)
print(f)
# Out:
# 13
# 35
# 10
# 1010
# 0b1010
# 10110
# 22

# %% [markdown]
# Bitwise Operator :
#  ![Screenshot 2025-07-08 132059.png](data:image/png;base64,...)
#  ![Screenshot 2025-07-08 133608.png](data:image/png;base64,...)

# %%
# 'AND' (&) Operator : Sets each bit to 1 if both bits are 1
a=4
c=6
print('A value is %s' %(bin(a)))
print('C value is %s' %bin(c))
d=a&c
print(d)
f="0100"
g = int(f, 2)
print(g)
# Out:
# A value is 0b100
# C value is 0b110
# 4
# 4

# %%
# 'OR' (|) Operator: Sets each bit to 1 if one of two bits is 1
a=23
c=99
print('A value is %s' %(bin(a)))
print('C value is %s' %bin(c))
d=a|c
print(d)
f="1110111"
g = int(f, 2)
print(g)
# Out:
# A value is 0b10111
# C value is 0b1100011
# 119
# 119

# %%
# 'XOR' (^) Operator: Sets each bit to 1 if only one of two bits is 1
print(a^b)
# Out:
# 41

# %%
# 'NOT' (~) Operator: Inverts all the bits
print(~a)
# Out:
# -14

# %%
# 'Zero fill left shift' (<<): Shift left by pushing zeros in from the right and let the leftmost bits fall off
a=23
c=2
print(bin(a))
print(a<<c)
f="01011100"
g = int(f, 2)
print(g)
# Out:
# 0b10111
# 92
# 92

# %%
# 'Signed right shift' (>>) : Shift right by pushing copies of the leftmost bit in from the left, and let the rightmost bits fall off
print(a>>b)
# Out:
# 0

# %% [markdown]
# # 6. Identity Operators
#
# ---
# Identity operators are used to compare the objects, not if they are equal, but if they are actually the same object, with the same memory location:

# %%
# 'is' Operator : Returns true if both variables are the same object
#Identity Operators

a=[1,3,5,7,'Python']
a=b
print(b is a)
# Out:
# True

# %%
# 'is not' Operator: Returns true if both variables are not the same object
print(a is not b)
# Out:
# False

# %% [markdown]
# # 7. Membership Operators
#
# ---
#
# Membership operators are used to test if a sequence is presented in an object:

# %%
# 'in' Operator: Returns True if a sequence with the specified value is present in the object
list1=[1,10,100,"Data Science"]
print(30 in list1)
# Out:
# False

# %%
# 'not in' Operator: Returns True if a sequence with the specified value is not present in the object
print(20 not in list1)
# Out:
# True

# %% [markdown]
# ---
# # 📝 Assignments – Python Operators
#
# Work through each task below. Every task maps directly to an operator category you just studied.
# Run your code in the cell provided, check the output, and compare it with the expected result.
#
# > **Tip:** Read the *Explanation* and *Hints* for each task before writing code.
# ---

# %% [markdown]
# ## 🔢 Task 1 – Arithmetic Operators
#
# **Problem:**
# You went to a shop and bought **3 notebooks** at ₹45 each and **2 pens** at ₹12 each.
# Calculate:
# 1. The **total cost**
# 2. The **average cost per item**
# 3. How many items you can buy if you have **₹200** (use floor division `//`)
# 4. The **change** you get back after buying as many items as possible (use modulus `%`)
#
# **Expected output:**
# ```
# Total cost: 159
# Average cost per item: 31.8
# Items you can buy with ₹200: 6
# Change remaining: 14
# ```
#
# **💡 Hints:**
# - Total items = 3 + 2 = 5
# - Total cost = (3 × 45) + (2 × 12)
# - Average = total_cost / total_items
# - For *how many items with ₹200*, use `200 // average_price_of_a_single_item` — but since items have different prices, a simpler approach is `200 // total_cost * total_items` ... or just try `200 // 31` (integer average price)
# - Remainder = `200 % 31`

# %%
# Task 1 – Your code here
notebook_price = 45
pen_price = 12

# 1. Total cost

# 2. Average cost per item

# 3. Items you can buy with ₹200

# 4. Change remaining

# %% [markdown]
# ## 📌 Task 2 – Assignment Operators
#
# **Problem:**
# A student scored **50 marks** in their first test.
# Use **only assignment operators** (`+=`, `-=`, `*=`, `//=`) to:
# 1. Add **10** bonus marks
# 2. Subtract **5** penalty marks
# 3. Double the score (multiply by 2)
# 4. Apply grade scaling — floor-divide by **3**
#
# Print the score after **each step**.
#
# **Expected output:**
# ```
# After bonus:   60
# After penalty: 55
# After double:  110
# After scaling: 36
# ```
#
# **💡 Hints:**
# - `score += 10` is the same as `score = score + 10`
# - You must use the shorthand operators for each step, not plain `=`

# %%
# Task 2 – Your code here
score = 50

# Step 1: Add 10 bonus marks using +=

# Step 2: Subtract 5 penalty marks using -=

# Step 3: Double the score using *=

# Step 4: Floor-divide by 3 using //=

# %% [markdown]
# ## ⚖️ Task 3 – Comparison Operators
#
# **Problem:**
# Two friends, Arjun (age **22**) and Priya (age **25**), are applying for a job.
# The minimum age requirement is **21**.
# Answer the following with `True` or `False` by printing the result of comparison expressions:
#
# 1. Is Arjun older than Priya?
# 2. Is Priya's age equal to Arjun's age?
# 3. Is Arjun's age not equal to Priya's age?
# 4. Does Arjun meet the minimum age requirement (`>=`)?
# 5. Is Priya's age less than or equal to 25?
#
# **Expected output:**
# ```
# Arjun older than Priya: False
# Ages equal: False
# Ages not equal: True
# Arjun meets requirement: True
# Priya age <= 25: True
# ```
#
# **💡 Hints:**
# - Comparison operators always return a boolean (`True` or `False`)
# - Use `==` for equality, `!=` for not-equal, `>=` for greater-than-or-equal

# %%
# Task 3 – Your code here
arjun_age = 22
priya_age = 25
min_age = 21

# 1. Is Arjun older than Priya?

# 2. Are their ages equal?

# 3. Are their ages not equal?

# 4. Does Arjun meet the minimum age requirement?

# 5. Is Priya's age <= 25?

# %% [markdown]
# ## 🔗 Task 4 – Logical Operators
#
# **Problem:**
# A ticket booking system has two rules:
# - Rule A: The user must be **18 or older**
# - Rule B: The user must have a **valid ID** (`has_id = True`)
#
# Given `age = 20` and `has_id = True`, check:
# 1. Can the user book? (both conditions must be true — use `and`)
# 2. Is **at least one** condition met? (use `or`)
# 3. Is the user **not** eligible (flip the result of condition 1 — use `not`)
#
# **Expected output:**
# ```
# Can book (both conditions): True
# At least one condition met: True
# Not eligible: False
# ```
#
# **💡 Hints:**
# - `and` requires ALL conditions to be True
# - `or` requires at least ONE condition to be True
# - `not` flips True → False and False → True

# %%
# Task 4 – Your code here
age = 20
has_id = True

# 1. Can the user book? (age >= 18 AND has_id)

# 2. At least one condition met?

# 3. Not eligible?

# %% [markdown]
# ## 🔍 Task 5 – Identity Operators
#
# **Problem:**
# Understand the difference between `==` (equality) and `is` (identity).
#
# ```python
# list_a = [1, 2, 3]
# list_b = [1, 2, 3]
# list_c = list_a
# ```
#
# Answer:
# 1. Are `list_a` and `list_b` **equal** in value? (`==`)
# 2. Are `list_a` and `list_b` the **same object in memory**? (`is`)
# 3. Are `list_a` and `list_c` the **same object in memory**? (`is`)
# 4. Is `list_b` **not** the same object as `list_a`? (`is not`)
#
# **Expected output:**
# ```
# list_a == list_b : True
# list_a is list_b : False
# list_a is list_c : True
# list_b is not list_a: True
# ```
#
# **💡 Hints:**
# - `==` compares **values**; `is` compares **memory addresses**
# - When you do `list_c = list_a`, both variables point to the **same** list in memory
# - Two separately created lists with identical values are **equal** (`==`) but NOT the same object (`is` returns False)

# %%
# Task 5 – Your code here
list_a = [1, 2, 3]
list_b = [1, 2, 3]
list_c = list_a

# 1. Are list_a and list_b equal in value?

# 2. Are list_a and list_b the same object?

# 3. Are list_a and list_c the same object?

# 4. Is list_b NOT the same object as list_a?

# %% [markdown]
# ## 🔎 Task 6 – Membership Operators
#
# **Problem:**
# You have a list of students who passed an exam:
# ```python
# passed = ["Anu", "Raj", "Meera", "Kiran", "Deepa"]
# ```
#
# Check:
# 1. Is `"Raj"` in the passed list? (use `in`)
# 2. Is `"Arjun"` in the passed list? (use `in`)
# 3. Is `"Meera"` **not** in the passed list? (use `not in`)
# 4. Is `"Priya"` **not** in the passed list? (use `not in`)
#
# **Expected output:**
# ```
# Raj passed: True
# Arjun passed: False
# Meera did not pass: False
# Priya did not pass: True
# ```
#
# **💡 Hints:**
# - `in` returns `True` if the item **exists** in the sequence
# - `not in` returns `True` if the item **does NOT exist** in the sequence
# - These operators work on lists, strings, tuples, and sets

# %%
# Task 6 – Your code here
passed = ["Anu", "Raj", "Meera", "Kiran", "Deepa"]

# 1. Is Raj in the list?

# 2. Is Arjun in the list?

# 3. Is Meera NOT in the list?

# 4. Is Priya NOT in the list?

# %% [markdown]
# ## 🚀 Bonus Challenge – Combine Everything!
#
# **Problem:**
# Build a simple **eligibility checker** for a college scholarship:
#
# Rules:
# - Marks must be **above 75** (use `>`)
# - Age must be **between 17 and 25** (inclusive, use `and` + `<=`)
# - The student must **not** have already received a scholarship (use `not`)
# - The student's name must be **in the approved list** (use `in`)
#
# ```python
# marks = 80
# age = 20
# already_received = False
# approved_list = ["Anu", "Raj", "Meera"]
# student_name = "Raj"
# ```
#
# Print `True` if the student is eligible, `False` otherwise.
#
# **Expected output:**
# ```
# Eligible for scholarship: True
# ```
#
# **💡 Hints:**
# - Chain all conditions with `and`
# - `not already_received` flips False → True (meaning they haven't received it yet — good!)
# - `student_name in approved_list` checks list membership

# %%
# Bonus Challenge – Your code here
marks = 80
age = 20
already_received = False
approved_list = ["Anu", "Raj", "Meera"]
student_name = "Raj"

# Write ONE expression combining all conditions
eligible = 
print('Eligible for scholarship:', eligible)
