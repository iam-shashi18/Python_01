# %% [markdown]
# **Hello World Program in Python**
#
# ---

# %%
print ("Hello World!!")
# Out:
# Hello World!!

# %%
a = "Hello World!! 1234 !@#$"
print(a)
# Out:
# Hello World!! 1234 !@#$

# %% [markdown]
# **String**
# - combination of characters within the single or double quotes
#  or it's a contiues series of characters surrounded by single or double quotes
#
#  ['hello' is the same as hello"]
#
# ---

# %%
a = "Hello World!!"
print(a)

print(type(a))
# Out:
# Hello World!!
# <class 'str'>

# %% [markdown]
# **Index() Method**
#
# The syntax of index() method for string is: str.index(sub[, start[, end]]). Indexing in string ( it start from 0 to n-1).
#
#  Square brackets [ ] can be used to access elements of the string
#
# ---

# %%
a = "Hello World"

print(a.index("e"))
print(a.index("World"))
# Out:
# 1
# 6

# %% [markdown]
# The **find() method** finds the first occurrence of the specified value.
#
# ---

# %%
a = "Hello World!"
print(a.find("e"))
# Out:
# 1

# %% [markdown]
# **Substring**. Get the characters from position 2 to position 5 (not included):
#
# ---

# %%
a = "Hello World"

print(a[1])
print(a[2:5])
# Out:
# e
# llo

# %% [markdown]
# The **strip() method** removes any whitespace from the beginning or the end:
#
# ---

# %%
a = " Hello World ! "
print(a.strip())
# Out:
# Hello World !

# %% [markdown]
# The **len() method** returns the length of a string:
#
# ---

# %%
a = "Hello World !"
print(len(a))
# Out:
# 13

# %% [markdown]
# The **lower() method** returns the string in lower case:
#
# ---

# %%
a = "Hello World !"
print(a.lower())
# Out:
# hello world !

# %% [markdown]
# The **upper() method** returns the string in upper case:
#
# ---

# %%
a = "Hello World !"
print(a.upper())
# Out:
# HELLO WORLD !

# %% [markdown]
# The **replace() method** replaces a string with another string:
#
# ---

# %%
a = "Hello World !"
print(a.replace("H",'J'))
# Out:
# Jello World !

# %% [markdown]
# The **split() method** splits the string into substrings if it finds instances of the separator:
#
# ---

# %%
a = "Hello World!"
print(a.split('@'))
# Out:
# ['Hello', 'World!']

# %% [markdown]
# The **join() method** takes all items in an iterable and joins them into one string.
#
#
# A string must be specified as the separator.
#
# ---

# %%
myTuple = ("John", "Peter", "Vicky")

x = "#".join(myTuple)

print(x)
# Out:
# John#Peter#Vicky

# %% [markdown]
# The **partition() method** searches for a specified string, and splits the string into a tuple containing three elements.
#
# ---

# %%
txt = "I could eat bananas all day"

x = txt.partition("bananas")

print(x)
# Out:
# ('I could eat ', 'bananas', ' all day')

# %% [markdown]
# **String Formatting**
#
# Python uses C-style string formatting to create new, formatted strings. The "%" operator is used to format a set of variables enclosed in a "tuple" (a fixed size list), together with a format string, which contains normal text together with "argument specifiers", special symbols like "%s" and "%d".
#
# Let's say you have a variable called "name" with your user name in it, and you would then like to print(out a greeting to that user.)
#
# ---
#
# **Example**:  This prints out "Hello, John!"

# %%
name = "John"
title='Mr.'
print("Hello, %s %s !" % (title,name))
# Out:
# Hello, Mr. John !

# %% [markdown]
# **Example ** : "This prints out "John is 23 years old."
#
# ---

# %%
name = "John"
age = 23
print("%s is %d years old is." % (name, age))
# Out:
# John is 23 years old is -10.

# %% [markdown]
# Any object which is not a string can be formatted using the %s operator as well. The string which returns from the "repr" method of that object is formatted as the string.
#
# ---
#
#
# For example:

# %%
mylist = [1,2,3]
print("A list: %s" % mylist)
# Out:
# A list: [1, 2, 3]

# %% [markdown]
# **Here are some basic argument specifiers you should know:**
#
# ---
#
#
#
# **%s** - String (or any object with a string representation, like numbers)
#
# **%d** - Integers
#
# **%f** - Floating point numbers upto 6 decimal points
#
# **%.<number of digits>f** - Floating point numbers with a fixed amount of digits to the right of the dot.
#
# **%x/%X -** Integers in hex representation (lowercase/uppercase)

# %% [markdown]
# ---
# ## f-Strings (Modern String Formatting — Python 3.6+)
#
# f-strings are the **preferred modern way** to embed variables inside strings. Just prefix the string with `f` and put variable names inside `{}`.
#
# ```python
# name = "Priya"
# age = 22
# print(f"My name is {name} and I am {age} years old.")
# # Output: My name is Priya and I am 22 years old.
# ```
#
# You can also do math inside `{}`:
# ```python
# price = 150
# qty = 3
# print(f"Total: ₹{price * qty}")
# # Output: Total: ₹450
# ```
#
# > **Tip:** f-strings are cleaner than `%` formatting or `.format()`. Use them whenever possible.

# %%
name = "Priya"
age = 22
city = "Bangalore"
print(f"My name is {name}, I am {age} years old, from {city}.")

price = 150
qty = 3
print(f"Total: ₹{price * qty}")

pi = 3.14159
print(f"Pi rounded to 2 decimals: {pi:.2f}")  # :.2f formats to 2 decimal places

# %% [markdown]
# ---
# ## Escape Characters
#
# Escape characters let you include special characters inside strings:
#
# | Escape | Meaning | Example |
# |--------|---------|--------|
# | `\n` | New line | `"Hello\nWorld"` prints on 2 lines |
# | `\t` | Tab (indent) | `"Name:\tRaj"` |
# | `\\` | Literal backslash | `"C:\\Users"` |
# | `\"` | Double quote inside double-quoted string | `"He said \"Hello\""` |
# | `\'` | Single quote inside single-quoted string | `'It\'s Python'` |

# %%
print("Hello\nWorld")          # newline
print("Name:\tRaj")            # tab
print("C:\\Users\\Documents")  # literal backslash
print("He said \"Hello!\"")     # quotes inside quotes
print('It\'s Python')          # apostrophe in single-quoted string

# %% [markdown]
# ---
# ## String Multiplication & Repetition
#
# Strings can be multiplied by an integer to repeat them — useful for formatting output:
#
# ```python
# print("ha" * 3)    # hahaha
# print("-" * 30)    # prints 30 dashes
# ```

# %%
print("ha" * 3)
print("-" * 40)
print("* " * 10)

# Practical use: section separators
print("=" * 20)
print("  STUDENT REPORT  ")
print("=" * 20)

# %% [markdown]
# ---
# # 📝 Assignments – String Methods
# ---

# %% [markdown]
# ## Task 1 – Name Formatter
#
# **Problem:** Clean up and format this messy name: `"   rAj kUmAr   "`
# 1. Strip the whitespace from both ends
# 2. Convert to title case (first letter of each word capitalized)
# 3. Print the cleaned name and its length
#
# **Expected output:**
# ```
# Raj Kumar
# 9
# ```
#
# **💡 Hints:**
# - `.strip()` removes leading/trailing whitespace
# - `.title()` capitalizes the first letter of each word
# - `len()` gives the length after stripping

# %%
# Task 1 – Name Formatter
full_name = "   rAj kUmAr   "

# %% [markdown]
# ## Task 2 – Email Validator
#
# **Problem:** Given `email = "student@example.com"`:
# 1. Check if `"@"` is in the email (print `True` or `False`)
# 2. Split at `"@"` and print the username and domain separately
#
# **Expected output:**
# ```
# Valid email: True
# Username: student
# Domain: example.com
# ```
#
# **💡 Hints:**
# - `"@" in email` checks if `@` exists
# - `.split("@")` returns a list of 2 parts: `["student", "example.com"]`

# %%
# Task 2 – Email Validator
email = "student@example.com"

# %% [markdown]
# ## Task 3 – Replace & Count
#
# **Problem:** Given: `sentence = "Python is easy. Python is powerful. Python is fun."`
# 1. Count how many times `"Python"` appears
# 2. Replace all `"Python"` with `"🐍 Python"`
# 3. Print the count and the new sentence
#
# **Expected output:**
# ```
# Python appears 3 times
# 🐍 Python is easy. 🐍 Python is powerful. 🐍 Python is fun.
# ```
#
# **💡 Hints:** `.count("Python")` counts occurrences; `.replace(old, new)` replaces all

# %%
# Task 3 – Replace & Count
sentence = "Python is easy. Python is powerful. Python is fun."

# %% [markdown]
# ## Task 4 – f-String Introduction
#
# **Problem:** Create variables `name`, `age`, `city` (use your own values), then print:
# `"Hi! I'm [name], [age] years old, from [city]."`
# Use an **f-string**.
#
# **Expected output:**
# ```
# Hi! I'm Raj, 21 years old, from Mumbai.
# ```
#
# **💡 Hint:** `f"Hi! I'm {name}, {age} years old, from {city}."`

# %%
# Task 4 – f-String
name = "Raj"
age = 21
city = "Mumbai"

# %% [markdown]
# ## Task 5 – Reverse a String
#
# **Problem:** Reverse the string `"Python"` using slicing.
#
# **Expected output:**
# ```
# nohtyP
# ```
#
# **💡 Hint:** Python slicing trick — `word[::-1]` reads the string backwards.
# `[start:stop:step]` — step of `-1` means go backwards.

# %%
# Task 5 – Reverse a string
word = "Python"

# %% [markdown]
# ## 🚀 Bonus – Word Counter
#
# **Problem:** Count how many words are in this sentence and print each word on its own line with its index:
# `"Learning Python is the best decision I ever made"`
#
# **Expected output:**
# ```
# Word count: 9
# 1: Learning
# 2: Python
# ...
# ```
#
# **💡 Hints:**
# - `.split()` splits by spaces → gives a list of words
# - `len()` on the list gives word count
# - Use `enumerate(words, 1)` to number from 1

# %%
# Bonus – Word Counter
sentence = "Learning Python is the best decision I ever made"
